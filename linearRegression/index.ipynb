# %%
from sklearn import datasets

from matplotlib import pyplot as plt
import numpy as np


x,y=datasets.make_regression(n_samples=100,n_features=1,noise=20,random_state=4)
# predictions produced out of the linearregression.java model
y_pred=[-47.29525067293084, 11.739256813766854, -87.95852267099536, -47.03413977925967, 66.88594025931278, -134.03207392156844, 36.63653304288242, 92.91301306059827, 50.755257591706126, 40.73651943679145, 31.177145577592956, -79.80532134557643, -40.99947426288997, 25.776354042000992, 61.271570467924136, 4.153982800785811, -0.49712307200398653, -171.74071863670775, -71.48414011244981, 68.33021239619646, 58.16544957982854, 37.36332803018212, -12.316086430065996, 11.843036236337303, 162.2894622665562, 24.409737843700807, 3.8717478294826764, -38.32520890548611, 31.55619711151468, 119.44689894951699, 57.536118591758665, -44.06254790729157, 28.93319517254801, 58.25862431150896, -78.21357583491235, -14.159288154664884, 61.176230323253456, -35.964577007744204, 100.79464097503617, 5.104596187130742, -72.425932904062, -65.82975028098184, -19.952538557336137, 17.877555204555136, 37.35305289035996, 24.409510365972537, -80.42229343950561, 152.41099766950313, 20.663028736367092, 45.2922326700502]
plt.scatter(x=x[int(len(x)/2):],y=y[int(len(x)/2):])
plt.plot(x[int(len(x)/2):],y_pred,color='black',linewidth=2)
# plt.plot(x[0:int(len(x)/2)],y[0:int(len(x)/2)],color='red',linewidth=2)
plt.figure(figsize=(10,8))

plt.show()
